# %%
FILE="data/euler2-tests.csv"
FILE="data/euler2-series.csv"
#TODO get metadata for serie 20

# %%
import pandas as pd
data = pd.read_csv(FILE)
if "index" in data.columns:
    data.set_index('index', inplace=True)
#data['date'] = pd.to_datetime(data['date'])
#data["is-counted"] = data["is-counted"].fillna(False)
#data["is-counted"] = data["is-counted"].fillna(False).infer_objects(copy=False)
#data["is-counted"] = data.get("is-counted",False)
if "is-counted" in data.columns:
    data["is-counted"] = data["is-counted"].astype(bool)
else:  
    data['is-counted'] = True
data
# Out:
#              date  note                                       info  is-counted
# index
# 0      2023-08-17  70.0                         que 3 exo donc fac       False
# 1      2023-08-23  52.0                     certains exo mal faits        True
# 2      2023-08-30  74.0                           très bon travail        True
# 3      2023-09-06  46.0               trop d'exo, mauvais en Monge        True
# 4      2023-09-13  45.0                       motié d'exo mal fait       False
# 5      2023-09-20  60.0                                  que 5 exo        True
# 6      2023-09-27  78.0          bon travail; bon en division eucl        True
# 7      2023-10-04  40.0                       certain exo mal fait        True
# 8      2023-10-11   NaN  le seul que j'ai bien fait mais c'est fac       False
# 9      2023-11-01  78.0                                  bien fait        True
# 10     2023-11-08  93.0                                      youpi        True
# 11     2023-11-15  98.0    bcp de couleurs -> excellent et parfait        True
# 12     2023-11-22  90.0                           théorème de Rado       False
# 13     2023-11-29  88.0                                        NaN        True
# 14     2023-12-06  58.0                                        NaN        True
# 15     2023-12-13  88.0                                        NaN        True
# 16     2023-12-20   NaN                                Joyeux noel       False
# 17     2024-01-10   NaN                                        fac       False
# 18     2024-01-17  72.0                     pas devoir non fait :)        True
# 19     2024-01-24  32.0                                    oh sh*t        True
# 20            NaN   NaN                                        NaN        True
# 21     2024-02-07  71.0                                        NaN        True
# 22     2024-02-21  56.0                                        NaN        True
# 23     2024-02-28  92.0                               wow (annexe)        True
# 24     2024-03-06  73.0                                        NaN        True
# 25     2024-03-13  61.0                             refaire qq exo       False

# %%
notes = data[data["is-counted"]]["note"]
notes
# Out:
# index
# 1     52.0
# 2     74.0
# 3     46.0
# 5     60.0
# 6     78.0
# 7     40.0
# 9     78.0
# 10    93.0
# 11    98.0
# 13    88.0
# 14    58.0
# 15    88.0
# 18    72.0
# 19    32.0
# 20     NaN
# 21    71.0
# 22    56.0
# 23    92.0
# 24    73.0
# Name: note, dtype: float64

# %%
notes.describe()
# Out:
# count    18.000000
# mean     69.388889
# std      19.220513
# min      32.000000
# 25%      56.500000
# 50%      72.500000
# 75%      85.500000
# max      98.000000
# Name: note, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.plot(notes.index,notes)

# %%
plt.show()
